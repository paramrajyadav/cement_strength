# %%
import pandas as pd
import pickle
import numpy as np
import matplotlib.pyplot as plot
import seaborn as sns
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.metrics  import r2_score

# %%
ds1=pd.read_csv("Training_File.csv")

# %%
ds=pd.DataFrame(ds1, columns=['Cement','Blast Furnace Slag _component_2','Fly Ash _component_3','Water_component_4','Superplasticizer_component_5','Coarse Aggregate_component_6','Fine Aggregate_component_7','Age_day','Concrete_compressive _strength'])

# %%
ds
# Out:
#       Cement  Blast Furnace Slag _component_2  Fly Ash _component_3  \
# 0      540.0                              0.0                   0.0
# 1      540.0                              0.0                   0.0
# 2      332.5                            142.5                   0.0
# 3      332.5                            142.5                   0.0
# 4      198.6                            132.4                   0.0
# ...      ...                              ...                   ...
# 1025   276.4                            116.0                  90.3
# 1026   322.2                              0.0                 115.6
# 1027   148.5                            139.4                 108.6
# 1028   159.1                            186.7                   0.0
# 1029   260.9                            100.5                  78.3
#
#       Water_component_4  Superplasticizer_component_5  \
# 0                 162.0                           2.5
# 1                 162.0                           2.5
# 2                 228.0                           0.0
# 3                 228.0                           0.0
# 4                 192.0                           0.0
# ...                 ...                           ...
# 1025              179.6                           8.9
# 1026              196.0                          10.4
# 1027              192.7                           6.1
# 1028              175.6                          11.3
# 1029              200.6                           8.6
#
#       Coarse Aggregate_component_6  Fine Aggregate_component_7  Age_day  \
# 0                           1040.0                       676.0       28
# 1                           1055.0                       676.0       28
# 2                            932.0                       594.0      270
# 3                            932.0                       594.0      365
# 4                            978.4                       825.5      360
# ...                            ...                         ...      ...
# 1025                         870.1                       768.3       28
# 1026                         817.9                       813.4       28
# 1027                         892.4                       780.0       28
# 1028                         989.6                       788.9       28
# 1029                         864.5                       761.5       28
#
#       Concrete_compressive _strength
# 0                              79.99
# 1                              61.89
# 2                              40.27
# 3                              41.05
# 4                              44.30
# ...                              ...
# 1025                           44.28
# 1026                           31.18
# 1027                           23.70
# 1028                           32.77
# 1029                           32.40
#
# [1030 rows x 9 columns]

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1030 entries, 0 to 1029
# Data columns (total 9 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Cement                           1030 non-null   float64
#  1   Blast Furnace Slag _component_2  1030 non-null   float64
#  2   Fly Ash _component_3             1030 non-null   float64
#  3   Water_component_4                1030 non-null   float64
#  4   Superplasticizer_component_5     1030 non-null   float64
#  5   Coarse Aggregate_component_6     1030 non-null   float64
#  6   Fine Aggregate_component_7       1030 non-null   float64
#  7   Age_day                          1030 non-null   int64
#  8   Concrete_compressive _strength   1030 non-null   float64
# dtypes: float64(8), int64(1)
# memory usage: 72.5 KB

# %%
ds.describe()
# Out:
#             Cement  Blast Furnace Slag _component_2  Fly Ash _component_3  \
# count  1030.000000                      1030.000000           1030.000000
# mean    281.167864                        73.895825             54.188350
# std     104.506364                        86.279342             63.997004
# min     102.000000                         0.000000              0.000000
# 25%     192.375000                         0.000000              0.000000
# 50%     272.900000                        22.000000              0.000000
# 75%     350.000000                       142.950000            118.300000
# max     540.000000                       359.400000            200.100000
#
#        Water_component_4  Superplasticizer_component_5  \
# count        1030.000000                   1030.000000
# mean          181.567282                      6.204660
# std            21.354219                      5.973841
# min           121.800000                      0.000000
# 25%           164.900000                      0.000000
# 50%           185.000000                      6.400000
# 75%           192.000000                     10.200000
# max           247.000000                     32.200000
#
#        Coarse Aggregate_component_6  Fine Aggregate_component_7      Age_day  \
# count                   1030.000000                 1030.000000  1030.000000
# mean                     972.918932                  773.580485    45.662136
# std                       77.753954                   80.175980    63.169912
# min                      801.000000                  594.000000     1.000000
# 25%                      932.000000                  730.950000     7.000000
# 50%                      968.000000                  779.500000    28.000000
# 75%                     1029.400000                  824.000000    56.000000
# max                     1145.000000                  992.600000   365.000000
#
#        Concrete_compressive _strength
# count                     1030.000000
# mean                        35.817961
# std                         16.705742
# min                          2.330000
# 25%                         23.710000
# 50%                         34.445000
# 75%                         46.135000
# max                         82.600000

# %%
ds.isna().sum()
# Out:
# Cement                             0
# Blast Furnace Slag _component_2    0
# Fly Ash _component_3               0
# Water_component_4                  0
# Superplasticizer_component_5       0
# Coarse Aggregate_component_6       0
# Fine Aggregate_component_7         0
# Age_day                            0
# Concrete_compressive _strength     0
# dtype: int64

# %%
plot.figure(figsize=(15,15),facecolor='white')
plotnumber = 1

for column in ds.columns:
    ax = plot.subplot(4,3,plotnumber)
    sns.histplot(ds[column])
    plot.xlabel(column,fontsize=10)
    plotnumber+=1
plot.show()

# %%
# ds22=ds1 
# for column in ds22.columns:
#      ds22[column]+=1
#      ds22[column] = np.log(ds22[column])

# %%
# plot.figure(figsize=(15,15),facecolor='white')
# plotnumber = 1

# for column in ds22.columns:
#     ax = plot.subplot(4,3,plotnumber)
#     sns.histplot(ds22[column])
#     plot.xlabel(column,fontsize=10)
#     plotnumber+=1
# plot.show()

# %%
X = ds1.drop(['Concrete_compressive _strength'],axis=1)
y = ds1['Concrete_compressive _strength']
C = ds1.drop(['Concrete_compressive _strength'],axis=1)

# %%
C
# Out:
#       Cement  Blast Furnace Slag _component_2  Fly Ash _component_3  \
# 0      540.0                              0.0                   0.0
# 1      540.0                              0.0                   0.0
# 2      332.5                            142.5                   0.0
# 3      332.5                            142.5                   0.0
# 4      198.6                            132.4                   0.0
# ...      ...                              ...                   ...
# 1025   276.4                            116.0                  90.3
# 1026   322.2                              0.0                 115.6
# 1027   148.5                            139.4                 108.6
# 1028   159.1                            186.7                   0.0
# 1029   260.9                            100.5                  78.3
#
#       Water_component_4  Superplasticizer_component_5  \
# 0                 162.0                           2.5
# 1                 162.0                           2.5
# 2                 228.0                           0.0
# 3                 228.0                           0.0
# 4                 192.0                           0.0
# ...                 ...                           ...
# 1025              179.6                           8.9
# 1026              196.0                          10.4
# 1027              192.7                           6.1
# 1028              175.6                          11.3
# 1029              200.6                           8.6
#
#       Coarse Aggregate_component_6  Fine Aggregate_component_7  Age_day
# 0                           1040.0                       676.0       28
# 1                           1055.0                       676.0       28
# 2                            932.0                       594.0      270
# 3                            932.0                       594.0      365
# 4                            978.4                       825.5      360
# ...                            ...                         ...      ...
# 1025                         870.1                       768.3       28
# 1026                         817.9                       813.4       28
# 1027                         892.4                       780.0       28
# 1028                         989.6                       788.9       28
# 1029                         864.5                       761.5       28
#
# [1030 rows x 8 columns]

# %%
ds
# Out:
#       Cement  Blast Furnace Slag _component_2  Fly Ash _component_3  \
# 0      540.0                              0.0                   0.0
# 1      540.0                              0.0                   0.0
# 2      332.5                            142.5                   0.0
# 3      332.5                            142.5                   0.0
# 4      198.6                            132.4                   0.0
# ...      ...                              ...                   ...
# 1025   276.4                            116.0                  90.3
# 1026   322.2                              0.0                 115.6
# 1027   148.5                            139.4                 108.6
# 1028   159.1                            186.7                   0.0
# 1029   260.9                            100.5                  78.3
#
#       Water_component_4  Superplasticizer_component_5  \
# 0                 162.0                           2.5
# 1                 162.0                           2.5
# 2                 228.0                           0.0
# 3                 228.0                           0.0
# 4                 192.0                           0.0
# ...                 ...                           ...
# 1025              179.6                           8.9
# 1026              196.0                          10.4
# 1027              192.7                           6.1
# 1028              175.6                          11.3
# 1029              200.6                           8.6
#
#       Coarse Aggregate_component_6  Fine Aggregate_component_7  Age_day  \
# 0                           1040.0                       676.0       28
# 1                           1055.0                       676.0       28
# 2                            932.0                       594.0      270
# 3                            932.0                       594.0      365
# 4                            978.4                       825.5      360
# ...                            ...                         ...      ...
# 1025                         870.1                       768.3       28
# 1026                         817.9                       813.4       28
# 1027                         892.4                       780.0       28
# 1028                         989.6                       788.9       28
# 1029                         864.5                       761.5       28
#
#       Concrete_compressive _strength
# 0                              79.99
# 1                              61.89
# 2                              40.27
# 3                              41.05
# 4                              44.30
# ...                              ...
# 1025                           44.28
# 1026                           31.18
# 1027                           23.70
# 1028                           32.77
# 1029                           32.40
#
# [1030 rows x 9 columns]

# %%
plot.figure(figsize=(15,15),facecolor='white')
plotnumber = 1

for column in X.columns:
    ax = plot.subplot(4,3,plotnumber)
    #data[column]+=1
    sns.boxplot((X[column]))
    plot.xlabel(column,fontsize=10)
    plotnumber+=1
plot.show()

# %%
plot.figure(figsize=(20,20),facecolor='white')
plotnumber = 1

for column in X.columns:
    ax = plot.subplot(4,3,plotnumber)
    sns.scatterplot(x=X[column],y=y)
    plot.xlabel(column,fontsize=10)
    plotnumber+=1
plot.show()

# %%
plot.figure(figsize=(8,8))
    #ax = plot.subplot(5,3,plotnumber)
sns.heatmap(X.corr().abs(), vmin = -0.5,vmax = 1,annot=True)
# Out:
# <Axes: >

# %%
from sklearn.cluster import KMeans
from kneed import KneeLocator
wcss=[]
for i in range (1,11):
  kmeans=KMeans(n_clusters=i,init='k-means++',random_state=42) # initializing the KMeans object
  kmeans.fit(X) # fitting the data to the KMeans Algorithm
  wcss.append(kmeans.inertia_)
kn = KneeLocator(range(1, 11), wcss, curve='convex', direction='decreasing')
s=kn.knee
# Out:
# C:\Users\Lakshita\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Lakshita\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=5.
#   warnings.warn(
# C:\Users\Lakshita\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Lakshita\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=5.
#   warnings.warn(
# C:\Users\Lakshita\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Lakshita\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=5.
#   warnings.warn(
# C:\Users\Lakshita\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Lakshita\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=5.
#   warnings.warn(
# C:\Users\Lakshita\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Lakshita\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=5.
#   warnings.warn(
# C:\Users\Lakshita\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Lakshita\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=5.
#   warnings.warn(
# C:\Users\Lakshita\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Lakshita\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=5.
#   warnings.warn(
# C:\Users\Lakshita\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Lakshita\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=5.
#   warnings.warn(
# C:\Users\Lakshita\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Lakshita\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=5.
#   warnings.warn(
# C:\Users\Lakshita\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Lakshita\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=5.
#   warnings.warn(

# %%
kmeans = KMeans(n_clusters=s, init='k-means++', random_state= 42)  
y_predict= kmeans.fit_predict(X)  
cluster=y_predict
# Out:
# C:\Users\Lakshita\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Lakshita\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=5.
#   warnings.warn(

# %%
z=y
z=pd.DataFrame(z)
cluster = pd.DataFrame(cluster)
z["Cluster"]=cluster

# %%
import os
original_path=os.getcwd()
for i in range(s):

# Define the folder path
    folder_path=os.getcwd() + "/" + str(i)
    print(folder_path)

# Check if the folder already exists
    if not os.path.exists(folder_path):
    # If the folder doesn't exist, create it
        os.makedirs(folder_path)
# Out:
# C:\Users\Lakshita\Desktop\New folder/0
# C:\Users\Lakshita\Desktop\New folder/1
# C:\Users\Lakshita\Desktop\New folder/2

# %%
kmeans = KMeans(n_clusters=s, init='k-means++', random_state= 42)  
y_predict= kmeans.fit_predict(X)
cluster=y_predict
# Out:
# C:\Users\Lakshita\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Lakshita\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=5.
#   warnings.warn(

# %%
X["Cluster"]=cluster

# %%
from sklearn.ensemble import RandomForestRegressor
def randomforest():
    
    

    # Define the model
    model = RandomForestRegressor(random_state=42)

    # Define the grid search parameters
    param_grid = {
    'n_estimators': [10, 50]#, 100, 200],
    ,'max_depth': [None, 5]#, 10, 15],
    ,'min_samples_split': [2]#, 5, 10],
    ,'min_samples_leaf': [1]#, 2, 4],
    ,'max_features': ['auto']#, 'sqrt', 'log2']
    }

    # Define the GridSearchCV object
    grid_search = GridSearchCV(model, param_grid=param_grid, cv=5, n_jobs=-1,verbose=2)

    # Fit the model with the GridSearchCV object
    grid_search.fit(X_train_scaled, y_train)

    # Print the best parameters and score
    print("Best Parameters:", grid_search.best_params_)
    print("Best Score:", grid_search.best_score_)

    # Fit the Random Forest Regressor with the best parameters
    best_model_2 = RandomForestRegressor(random_state=42, **grid_search.best_params_)
    best_model_2.fit(X_train_scaled, y_train)
    predict_clf=best_model_2.predict(X_test_scaled)
    global randomForest_error
    randomForest_error = r2_score(y_test,predict_clf)
    return best_model_2

# %%
from xgboost import XGBRegressor
def xg_boost():
    param_grid_xgboost = {

    'learning_rate': [0.5, 0.1]#, 0.01, 0.001],
    ,'max_depth': [3, 5]#, 10, 20],
    ,'n_estimators': [10, 50]#, 100, 200]
    }
    xgb1 = XGBRegressor()
    # Creating an object of the Grid Search class
    grid= GridSearchCV(#XGBRegressor(objective='reg:squarederror'),
        xgb1,
                       param_grid_xgboost, verbose=3,cv=5)
    # finding the best parameters
    grid.fit(X_train_scaled, y_train)

    # extracting the best parameters
    learning_rate = grid.best_params_['learning_rate']
    max_depth = grid.best_params_['max_depth']
    n_estimators = grid.best_params_['n_estimators']
    print(learning_rate,max_depth,n_estimators)
    print(grid.best_params_)

  # creating a new model with the best parameters
    xgb =XGBRegressor(
    max_depth=max_depth,
    learning_rate=learning_rate,
    n_estimators=n_estimators,
    verbosity=1)#,
    #objective='reg:squarederror')
  # training the mew model
    xgb.fit(X_train_scaled, y_train)
    predict_xgb=xgb.predict(X_test_scaled)
    global xgb_error
    xgb_error = r2_score(y_test,predict_xgb)
    return xgb

# %%
from sklearn.tree import DecisionTreeRegressor
def decession_tree():
    param_grid_decisionTree = {'criterion': ['squared_error', 'friedman_mse',],
                                'max_depth': [5, 10]#, 15, 20, 25, 30],
                                ,'max_features': [None, 'sqrt', 'log2'],
                                'max_depth': range(2, 3, 1),
                                'min_samples_split': range(2, 3, 1),
                             'splitter': ['best', 'random']
                              }
    dt=DecisionTreeRegressor()
    # Creating an object of the Grid Search class
    grid = GridSearchCV(dt, param_grid_decisionTree, verbose=3,cv=5)
    # finding the best parameters
    grid.fit(X_train_scaled, y_train)

    # extracting the best parameters
    criterion = grid.best_params_['criterion']
    splitter = grid.best_params_['splitter']
    max_features = grid.best_params_['max_features']
    max_depth  = grid.best_params_['max_depth']
    min_samples_split = grid.best_params_['min_samples_split']

    # creating a new model with the best parameters
    decisionTreeReg = DecisionTreeRegressor(criterion=criterion,splitter=splitter,max_features=max_features,max_depth=max_depth,min_samples_split=min_samples_split)
    # training the mew models
    decisionTreeReg.fit(X_train_scaled, y_train)
    predict_dt=decisionTreeReg.predict(X_test_scaled)
    global dt_error
    dt_error=r2_score(y_test,predict_dt)
    return decisionTreeReg

# %%
from sklearn.preprocessing import MinMaxScaler
model={}
error=[]

# %%
from sklearn.preprocessing import RobustScaler

# Create an instance of StandardScaler
scaler = RobustScaler()

# Fit and transform the data
X_scaled = scaler.fit_transform(C)

# Convert the scaled data to a DataFrame
df_scaled = pd.DataFrame(X_scaled, columns=['Cement','Blast Furnace Slag _component_2','Fly Ash _component_3','Water_component_4','Superplasticizer_component_5','Coarse Aggregate_component_6','Fine Aggregate_component_7','Age_day'])

# Print the transformed data
print(df_scaled)
# Out:
#         Cement  Blast Furnace Slag _component_2  Fly Ash _component_3  \
# 0     1.694528                        -0.153900              0.000000
# 1     1.694528                        -0.153900              0.000000
# 2     0.378113                         0.842952              0.000000
# 3     0.378113                         0.842952              0.000000
# 4    -0.471372                         0.772298              0.000000
# ...        ...                              ...                   ...
# 1025  0.022205                         0.657573              0.763314
# 1026  0.312768                        -0.153900              0.977177
# 1027 -0.789215                         0.821266              0.918005
# 1028 -0.721967                         1.152151              0.000000
# 1029 -0.076130                         0.549143              0.661877
#
#       Water_component_4  Superplasticizer_component_5  \
# 0             -0.848708                     -0.382353
# 1             -0.848708                     -0.382353
# 2              1.586716                     -0.627451
# 3              1.586716                     -0.627451
# 4              0.258303                     -0.627451
# ...                 ...                           ...
# 1025          -0.199262                      0.245098
# 1026           0.405904                      0.392157
# 1027           0.284133                     -0.029412
# 1028          -0.346863                      0.480392
# 1029           0.575646                      0.215686
#
#       Coarse Aggregate_component_6  Fine Aggregate_component_7   Age_day
# 0                         0.739220                   -1.112305  0.000000
# 1                         0.893224                   -1.112305  0.000000
# 2                        -0.369610                   -1.993552  4.938776
# 3                        -0.369610                   -1.993552  6.877551
# 4                         0.106776                    0.494358  6.775510
# ...                            ...                         ...       ...
# 1025                     -1.005133                   -0.120365  0.000000
# 1026                     -1.541068                    0.364320  0.000000
# 1027                     -0.776181                    0.005373  0.000000
# 1028                      0.221766                    0.101021  0.000000
# 1029                     -1.062628                   -0.193444  0.000000
#
# [1030 rows x 8 columns]

# %%
list_of_clusters=X['Cluster'].unique()    
for i in list_of_clusters:

    cluster_data=X[X['Cluster']==i]
    cluster_data=cluster_data.drop("Cluster",axis=1)
    cluster_data_2=z[z['Cluster']==i]
    cluster_data2=cluster_data_2.drop("Cluster",axis=1)# filter the data for one cluster
    X_train, X_test, y_train, y_test = train_test_split(cluster_data, cluster_data_2, test_size=0.2, random_state=42)

    
    X_train_scaled = scaler.transform(X_train)
    X_test_scaled = scaler.transform(X_test)
    dtdt=decession_tree()
    xgbxgb=xg_boost()
    rfrf=randomforest()
    error.append(randomForest_error)

    error.append(xgb_error)
    error.append(dt_error)



    if randomForest_error < xgb_error and randomForest_error < dt_error:
        model[i]=dtdt
        pickle.dump(dtdt, open(str(i)+"/"+'model_.pkl', 'wb'))

    elif xgb_error < dt_error and xgb_error < randomForest_error:
        model[i]=xgbxgb



        pickle.dump(xgbxgb, open(str(i)+"/"+'model_.pkl', 'wb'))
    else:
        model[i]=dtdt

        pickle.dump(dtdt, open(str(i)+"/"+'model_.pkl', 'wb'))
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV 1/5] END criterion=squared_error, max_depth=2, max_features=None, min_samples_split=2, splitter=best;, score=0.759 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=2, max_features=None, min_samples_split=2, splitter=best;, score=0.749 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=2, max_features=None, min_samples_split=2, splitter=best;, score=0.827 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=2, max_features=None, min_samples_split=2, splitter=best;, score=0.712 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=2, max_features=None, min_samples_split=2, splitter=best;, score=0.698 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=2, max_features=None, min_samples_split=2, splitter=random;, score=0.613 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=2, max_features=None, min_samples_split=2, splitter=random;, score=0.591 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=2, max_features=None, min_samples_split=2, splitter=random;, score=0.616 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=2, max_features=None, min_samples_split=2, splitter=random;, score=0.654 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=2, max_features=None, min_samples_split=2, splitter=random;, score=0.620 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=2, max_features=sqrt, min_samples_split=2, splitter=best;, score=0.783 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=2, max_features=sqrt, min_samples_split=2, splitter=best;, score=0.720 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=2, max_features=sqrt, min_samples_split=2, splitter=best;, score=0.690 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=2, max_features=sqrt, min_samples_split=2, splitter=best;, score=0.631 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=2, max_features=sqrt, min_samples_split=2, splitter=best;, score=0.560 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=2, max_features=sqrt, min_samples_split=2, splitter=random;, score=0.601 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=2, max_features=sqrt, min_samples_split=2, splitter=random;, score=0.632 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=2, max_features=sqrt, min_samples_split=2, splitter=random;, score=0.536 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=2, max_features=sqrt, min_samples_split=2, splitter=random;, score=0.542 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=2, max_features=sqrt, min_samples_split=2, splitter=random;, score=0.528 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=2, max_features=log2, min_samples_split=2, splitter=best;, score=0.705 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=2, max_features=log2, min_samples_split=2, splitter=best;, score=0.749 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=2, max_features=log2, min_samples_split=2, splitter=best;, score=0.770 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=2, max_features=log2, min_samples_split=2, splitter=best;, score=0.688 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=2, max_features=log2, min_samples_split=2, splitter=best;, score=0.703 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=2, max_features=log2, min_samples_split=2, splitter=random;, score=0.629 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=2, max_features=log2, min_samples_split=2, splitter=random;, score=0.658 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=2, max_features=log2, min_samples_split=2, splitter=random;, score=0.653 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=2, max_features=log2, min_samples_split=2, splitter=random;, score=0.662 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=2, max_features=log2, min_samples_split=2, splitter=random;, score=0.594 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=2, max_features=None, min_samples_split=2, splitter=best;, score=0.759 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=2, max_features=None, min_samples_split=2, splitter=best;, score=0.749 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=2, max_features=None, min_samples_split=2, splitter=best;, score=0.827 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=2, max_features=None, min_samples_split=2, splitter=best;, score=0.712 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=2, max_features=None, min_samples_split=2, splitter=best;, score=0.698 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=2, max_features=None, min_samples_split=2, splitter=random;, score=0.632 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=2, max_features=None, min_samples_split=2, splitter=random;, score=0.693 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=2, max_features=None, min_samples_split=2, splitter=random;, score=0.592 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=2, max_features=None, min_samples_split=2, splitter=random;, score=0.616 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=2, max_features=None, min_samples_split=2, splitter=random;, score=0.632 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=2, max_features=sqrt, min_samples_split=2, splitter=best;, score=0.748 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=2, max_features=sqrt, min_samples_split=2, splitter=best;, score=0.673 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=2, max_features=sqrt, min_samples_split=2, splitter=best;, score=0.676 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=2, max_features=sqrt, min_samples_split=2, splitter=best;, score=0.617 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=2, max_features=sqrt, min_samples_split=2, splitter=best;, score=0.715 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=2, max_features=sqrt, min_samples_split=2, splitter=random;, score=0.541 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=2, max_features=sqrt, min_samples_split=2, splitter=random;, score=0.661 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=2, max_features=sqrt, min_samples_split=2, splitter=random;, score=0.610 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=2, max_features=sqrt, min_samples_split=2, splitter=random;, score=0.564 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=2, max_features=sqrt, min_samples_split=2, splitter=random;, score=0.603 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=2, max_features=log2, min_samples_split=2, splitter=best;, score=0.770 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=2, max_features=log2, min_samples_split=2, splitter=best;, score=0.717 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=2, max_features=log2, min_samples_split=2, splitter=best;, score=0.826 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=2, max_features=log2, min_samples_split=2, splitter=best;, score=0.773 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=2, max_features=log2, min_samples_split=2, splitter=best;, score=0.693 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=2, max_features=log2, min_samples_split=2, splitter=random;, score=0.643 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=2, max_features=log2, min_samples_split=2, splitter=random;, score=0.560 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=2, max_features=log2, min_samples_split=2, splitter=random;, score=0.576 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=2, max_features=log2, min_samples_split=2, splitter=random;, score=0.555 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=2, max_features=log2, min_samples_split=2, splitter=random;, score=0.509 total time=   0.0s
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# [CV 1/5] END learning_rate=0.5, max_depth=3, n_estimators=10;, score=0.452 total time=   0.0s
# [CV 2/5] END learning_rate=0.5, max_depth=3, n_estimators=10;, score=0.442 total time=   0.0s
# [CV 3/5] END learning_rate=0.5, max_depth=3, n_estimators=10;, score=0.454 total time=   0.0s
# [CV 4/5] END learning_rate=0.5, max_depth=3, n_estimators=10;, score=0.409 total time=   0.0s
# [CV 5/5] END learning_rate=0.5, max_depth=3, n_estimators=10;, score=0.430 total time=   0.0s
# [CV 1/5] END learning_rate=0.5, max_depth=3, n_estimators=50;, score=0.463 total time=   0.0s
# [CV 2/5] END learning_rate=0.5, max_depth=3, n_estimators=50;, score=0.462 total time=   0.0s
# [CV 3/5] END learning_rate=0.5, max_depth=3, n_estimators=50;, score=0.471 total time=   0.0s
# [CV 4/5] END learning_rate=0.5, max_depth=3, n_estimators=50;, score=0.445 total time=   0.0s
# [CV 5/5] END learning_rate=0.5, max_depth=3, n_estimators=50;, score=0.427 total time=   0.0s
# [CV 1/5] END learning_rate=0.5, max_depth=5, n_estimators=10;, score=0.460 total time=   0.0s
# [CV 2/5] END learning_rate=0.5, max_depth=5, n_estimators=10;, score=0.446 total time=   0.0s
# [CV 3/5] END learning_rate=0.5, max_depth=5, n_estimators=10;, score=0.459 total time=   0.0s
# [CV 4/5] END learning_rate=0.5, max_depth=5, n_estimators=10;, score=0.429 total time=   0.0s
# [CV 5/5] END learning_rate=0.5, max_depth=5, n_estimators=10;, score=0.432 total time=   0.0s
# [CV 1/5] END learning_rate=0.5, max_depth=5, n_estimators=50;, score=0.466 total time=   0.0s
# [CV 2/5] END learning_rate=0.5, max_depth=5, n_estimators=50;, score=0.455 total time=   0.0s
# [CV 3/5] END learning_rate=0.5, max_depth=5, n_estimators=50;, score=0.457 total time=   0.0s
# [CV 4/5] END learning_rate=0.5, max_depth=5, n_estimators=50;, score=0.442 total time=   0.0s
# [CV 5/5] END learning_rate=0.5, max_depth=5, n_estimators=50;, score=0.440 total time=   0.0s
# [CV 1/5] END learning_rate=0.1, max_depth=3, n_estimators=10;, score=-0.036 total time=   0.0s
# [CV 2/5] END learning_rate=0.1, max_depth=3, n_estimators=10;, score=-0.041 total time=   0.0s
# [CV 3/5] END learning_rate=0.1, max_depth=3, n_estimators=10;, score=-0.020 total time=   0.0s
# [CV 4/5] END learning_rate=0.1, max_depth=3, n_estimators=10;, score=-0.248 total time=   0.0s
# [CV 5/5] END learning_rate=0.1, max_depth=3, n_estimators=10;, score=-0.316 total time=   0.0s
# [CV 1/5] END learning_rate=0.1, max_depth=3, n_estimators=50;, score=0.443 total time=   0.0s
# [CV 2/5] END learning_rate=0.1, max_depth=3, n_estimators=50;, score=0.448 total time=   0.0s
# [CV 3/5] END learning_rate=0.1, max_depth=3, n_estimators=50;, score=0.448 total time=   0.0s
# [CV 4/5] END learning_rate=0.1, max_depth=3, n_estimators=50;, score=0.432 total time=   0.0s
# [CV 5/5] END learning_rate=0.1, max_depth=3, n_estimators=50;, score=0.443 total time=   0.0s
# [CV 1/5] END learning_rate=0.1, max_depth=5, n_estimators=10;, score=-0.029 total time=   0.0s
# [CV 2/5] END learning_rate=0.1, max_depth=5, n_estimators=10;, score=-0.039 total time=   0.0s
# [CV 3/5] END learning_rate=0.1, max_depth=5, n_estimators=10;, score=-0.021 total time=   0.0s
# [CV 4/5] END learning_rate=0.1, max_depth=5, n_estimators=10;, score=-0.221 total time=   0.0s
# [CV 5/5] END learning_rate=0.1, max_depth=5, n_estimators=10;, score=-0.302 total time=   0.0s
# [CV 1/5] END learning_rate=0.1, max_depth=5, n_estimators=50;, score=0.457 total time=   0.0s
# [CV 2/5] END learning_rate=0.1, max_depth=5, n_estimators=50;, score=0.457 total time=   0.0s
# [CV 3/5] END learning_rate=0.1, max_depth=5, n_estimators=50;, score=0.465 total time=   0.0s
# [CV 4/5] END learning_rate=0.1, max_depth=5, n_estimators=50;, score=0.440 total time=   0.0s
# [CV 5/5] END learning_rate=0.1, max_depth=5, n_estimators=50;, score=0.442 total time=   0.0s
# 0.5 3 50
# {'learning_rate': 0.5, 'max_depth': 3, 'n_estimators': 50}
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# C:\Users\Lakshita\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# C:\Users\Lakshita\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# Best Parameters: {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 50}
# Best Score: 0.9425809894104225
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV 1/5] END criterion=squared_error, max_depth=2, max_features=None, min_samples_split=2, splitter=best;, score=0.785 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=2, max_features=None, min_samples_split=2, splitter=best;, score=0.773 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=2, max_features=None, min_samples_split=2, splitter=best;, score=0.800 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=2, max_features=None, min_samples_split=2, splitter=best;, score=0.620 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=2, max_features=None, min_samples_split=2, splitter=best;, score=0.755 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=2, max_features=None, min_samples_split=2, splitter=random;, score=0.701 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=2, max_features=None, min_samples_split=2, splitter=random;, score=0.712 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=2, max_features=None, min_samples_split=2, splitter=random;, score=0.673 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=2, max_features=None, min_samples_split=2, splitter=random;, score=0.560 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=2, max_features=None, min_samples_split=2, splitter=random;, score=0.669 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=2, max_features=sqrt, min_samples_split=2, splitter=best;, score=0.605 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=2, max_features=sqrt, min_samples_split=2, splitter=best;, score=0.676 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=2, max_features=sqrt, min_samples_split=2, splitter=best;, score=0.543 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=2, max_features=sqrt, min_samples_split=2, splitter=best;, score=0.510 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=2, max_features=sqrt, min_samples_split=2, splitter=best;, score=0.520 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=2, max_features=sqrt, min_samples_split=2, splitter=random;, score=0.674 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=2, max_features=sqrt, min_samples_split=2, splitter=random;, score=0.665 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=2, max_features=sqrt, min_samples_split=2, splitter=random;, score=0.586 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=2, max_features=sqrt, min_samples_split=2, splitter=random;, score=0.541 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=2, max_features=sqrt, min_samples_split=2, splitter=random;, score=0.571 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=2, max_features=log2, min_samples_split=2, splitter=best;, score=0.826 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=2, max_features=log2, min_samples_split=2, splitter=best;, score=0.779 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=2, max_features=log2, min_samples_split=2, splitter=best;, score=0.778 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=2, max_features=log2, min_samples_split=2, splitter=best;, score=0.535 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=2, max_features=log2, min_samples_split=2, splitter=best;, score=0.681 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=2, max_features=log2, min_samples_split=2, splitter=random;, score=0.668 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=2, max_features=log2, min_samples_split=2, splitter=random;, score=0.628 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=2, max_features=log2, min_samples_split=2, splitter=random;, score=0.585 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=2, max_features=log2, min_samples_split=2, splitter=random;, score=0.523 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=2, max_features=log2, min_samples_split=2, splitter=random;, score=0.688 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=2, max_features=None, min_samples_split=2, splitter=best;, score=0.785 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=2, max_features=None, min_samples_split=2, splitter=best;, score=0.773 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=2, max_features=None, min_samples_split=2, splitter=best;, score=0.800 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=2, max_features=None, min_samples_split=2, splitter=best;, score=0.620 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=2, max_features=None, min_samples_split=2, splitter=best;, score=0.755 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=2, max_features=None, min_samples_split=2, splitter=random;, score=0.766 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=2, max_features=None, min_samples_split=2, splitter=random;, score=0.675 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=2, max_features=None, min_samples_split=2, splitter=random;, score=0.606 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=2, max_features=None, min_samples_split=2, splitter=random;, score=0.559 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=2, max_features=None, min_samples_split=2, splitter=random;, score=0.632 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=2, max_features=sqrt, min_samples_split=2, splitter=best;, score=0.694 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=2, max_features=sqrt, min_samples_split=2, splitter=best;, score=0.598 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=2, max_features=sqrt, min_samples_split=2, splitter=best;, score=0.657 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=2, max_features=sqrt, min_samples_split=2, splitter=best;, score=0.579 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=2, max_features=sqrt, min_samples_split=2, splitter=best;, score=0.631 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=2, max_features=sqrt, min_samples_split=2, splitter=random;, score=0.656 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=2, max_features=sqrt, min_samples_split=2, splitter=random;, score=0.540 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=2, max_features=sqrt, min_samples_split=2, splitter=random;, score=0.515 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=2, max_features=sqrt, min_samples_split=2, splitter=random;, score=0.516 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=2, max_features=sqrt, min_samples_split=2, splitter=random;, score=0.575 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=2, max_features=log2, min_samples_split=2, splitter=best;, score=0.826 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=2, max_features=log2, min_samples_split=2, splitter=best;, score=0.773 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=2, max_features=log2, min_samples_split=2, splitter=best;, score=0.720 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=2, max_features=log2, min_samples_split=2, splitter=best;, score=0.598 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=2, max_features=log2, min_samples_split=2, splitter=best;, score=0.750 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=2, max_features=log2, min_samples_split=2, splitter=random;, score=0.690 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=2, max_features=log2, min_samples_split=2, splitter=random;, score=0.672 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=2, max_features=log2, min_samples_split=2, splitter=random;, score=0.667 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=2, max_features=log2, min_samples_split=2, splitter=random;, score=0.516 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=2, max_features=log2, min_samples_split=2, splitter=random;, score=0.517 total time=   0.0s
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# [CV 1/5] END learning_rate=0.5, max_depth=3, n_estimators=10;, score=0.440 total time=   0.0s
# [CV 2/5] END learning_rate=0.5, max_depth=3, n_estimators=10;, score=0.403 total time=   0.0s
# [CV 3/5] END learning_rate=0.5, max_depth=3, n_estimators=10;, score=0.455 total time=   0.0s
# [CV 4/5] END learning_rate=0.5, max_depth=3, n_estimators=10;, score=0.417 total time=   0.0s
# [CV 5/5] END learning_rate=0.5, max_depth=3, n_estimators=10;, score=0.427 total time=   0.0s
# [CV 1/5] END learning_rate=0.5, max_depth=3, n_estimators=50;, score=0.462 total time=   0.0s
# [CV 2/5] END learning_rate=0.5, max_depth=3, n_estimators=50;, score=0.418 total time=   0.0s
# [CV 3/5] END learning_rate=0.5, max_depth=3, n_estimators=50;, score=0.480 total time=   0.0s
# [CV 4/5] END learning_rate=0.5, max_depth=3, n_estimators=50;, score=0.431 total time=   0.0s
# [CV 5/5] END learning_rate=0.5, max_depth=3, n_estimators=50;, score=0.439 total time=   0.0s
# [CV 1/5] END learning_rate=0.5, max_depth=5, n_estimators=10;, score=0.445 total time=   0.0s
# [CV 2/5] END learning_rate=0.5, max_depth=5, n_estimators=10;, score=0.419 total time=   0.0s
# [CV 3/5] END learning_rate=0.5, max_depth=5, n_estimators=10;, score=0.470 total time=   0.0s
# [CV 4/5] END learning_rate=0.5, max_depth=5, n_estimators=10;, score=0.404 total time=   0.0s
# [CV 5/5] END learning_rate=0.5, max_depth=5, n_estimators=10;, score=0.415 total time=   0.0s
# [CV 1/5] END learning_rate=0.5, max_depth=5, n_estimators=50;, score=0.446 total time=   0.0s
# [CV 2/5] END learning_rate=0.5, max_depth=5, n_estimators=50;, score=0.423 total time=   0.0s
# [CV 3/5] END learning_rate=0.5, max_depth=5, n_estimators=50;, score=0.476 total time=   0.0s
# [CV 4/5] END learning_rate=0.5, max_depth=5, n_estimators=50;, score=0.414 total time=   0.0s
# [CV 5/5] END learning_rate=0.5, max_depth=5, n_estimators=50;, score=0.416 total time=   0.0s
# [CV 1/5] END learning_rate=0.1, max_depth=3, n_estimators=10;, score=0.034 total time=   0.0s
# [CV 2/5] END learning_rate=0.1, max_depth=3, n_estimators=10;, score=0.036 total time=   0.0s
# [CV 3/5] END learning_rate=0.1, max_depth=3, n_estimators=10;, score=0.062 total time=   0.0s
# [CV 4/5] END learning_rate=0.1, max_depth=3, n_estimators=10;, score=-0.158 total time=   0.0s
# [CV 5/5] END learning_rate=0.1, max_depth=3, n_estimators=10;, score=0.023 total time=   0.0s
# [CV 1/5] END learning_rate=0.1, max_depth=3, n_estimators=50;, score=0.437 total time=   0.0s
# [CV 2/5] END learning_rate=0.1, max_depth=3, n_estimators=50;, score=0.406 total time=   0.0s
# [CV 3/5] END learning_rate=0.1, max_depth=3, n_estimators=50;, score=0.461 total time=   0.0s
# [CV 4/5] END learning_rate=0.1, max_depth=3, n_estimators=50;, score=0.426 total time=   0.0s
# [CV 5/5] END learning_rate=0.1, max_depth=3, n_estimators=50;, score=0.420 total time=   0.0s
# [CV 1/5] END learning_rate=0.1, max_depth=5, n_estimators=10;, score=0.057 total time=   0.0s
# [CV 2/5] END learning_rate=0.1, max_depth=5, n_estimators=10;, score=0.042 total time=   0.0s
# [CV 3/5] END learning_rate=0.1, max_depth=5, n_estimators=10;, score=0.070 total time=   0.0s
# [CV 4/5] END learning_rate=0.1, max_depth=5, n_estimators=10;, score=-0.207 total time=   0.0s
# [CV 5/5] END learning_rate=0.1, max_depth=5, n_estimators=10;, score=0.031 total time=   0.0s
# [CV 1/5] END learning_rate=0.1, max_depth=5, n_estimators=50;, score=0.450 total time=   0.0s
# [CV 2/5] END learning_rate=0.1, max_depth=5, n_estimators=50;, score=0.416 total time=   0.0s
# [CV 3/5] END learning_rate=0.1, max_depth=5, n_estimators=50;, score=0.477 total time=   0.0s
# [CV 4/5] END learning_rate=0.1, max_depth=5, n_estimators=50;, score=0.419 total time=   0.0s
# [CV 5/5] END learning_rate=0.1, max_depth=5, n_estimators=50;, score=0.426 total time=   0.0s
# 0.5 3 50
# {'learning_rate': 0.5, 'max_depth': 3, 'n_estimators': 50}
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# C:\Users\Lakshita\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# C:\Users\Lakshita\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# Best Parameters: {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 50}
# Best Score: 0.9347518018966081
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV 1/5] END criterion=squared_error, max_depth=2, max_features=None, min_samples_split=2, splitter=best;, score=0.798 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=2, max_features=None, min_samples_split=2, splitter=best;, score=0.815 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=2, max_features=None, min_samples_split=2, splitter=best;, score=0.837 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=2, max_features=None, min_samples_split=2, splitter=best;, score=0.677 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=2, max_features=None, min_samples_split=2, splitter=best;, score=0.829 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=2, max_features=None, min_samples_split=2, splitter=random;, score=0.670 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=2, max_features=None, min_samples_split=2, splitter=random;, score=0.761 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=2, max_features=None, min_samples_split=2, splitter=random;, score=0.803 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=2, max_features=None, min_samples_split=2, splitter=random;, score=0.652 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=2, max_features=None, min_samples_split=2, splitter=random;, score=0.749 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=2, max_features=sqrt, min_samples_split=2, splitter=best;, score=0.662 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=2, max_features=sqrt, min_samples_split=2, splitter=best;, score=0.769 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=2, max_features=sqrt, min_samples_split=2, splitter=best;, score=0.520 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=2, max_features=sqrt, min_samples_split=2, splitter=best;, score=0.595 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=2, max_features=sqrt, min_samples_split=2, splitter=best;, score=0.739 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=2, max_features=sqrt, min_samples_split=2, splitter=random;, score=0.632 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=2, max_features=sqrt, min_samples_split=2, splitter=random;, score=0.547 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=2, max_features=sqrt, min_samples_split=2, splitter=random;, score=0.611 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=2, max_features=sqrt, min_samples_split=2, splitter=random;, score=0.630 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=2, max_features=sqrt, min_samples_split=2, splitter=random;, score=0.493 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=2, max_features=log2, min_samples_split=2, splitter=best;, score=0.593 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=2, max_features=log2, min_samples_split=2, splitter=best;, score=0.815 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=2, max_features=log2, min_samples_split=2, splitter=best;, score=0.529 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=2, max_features=log2, min_samples_split=2, splitter=best;, score=0.501 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=2, max_features=log2, min_samples_split=2, splitter=best;, score=0.790 total time=   0.0s
# [CV 1/5] END criterion=squared_error, max_depth=2, max_features=log2, min_samples_split=2, splitter=random;, score=0.535 total time=   0.0s
# [CV 2/5] END criterion=squared_error, max_depth=2, max_features=log2, min_samples_split=2, splitter=random;, score=0.589 total time=   0.0s
# [CV 3/5] END criterion=squared_error, max_depth=2, max_features=log2, min_samples_split=2, splitter=random;, score=0.597 total time=   0.0s
# [CV 4/5] END criterion=squared_error, max_depth=2, max_features=log2, min_samples_split=2, splitter=random;, score=0.555 total time=   0.0s
# [CV 5/5] END criterion=squared_error, max_depth=2, max_features=log2, min_samples_split=2, splitter=random;, score=0.619 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=2, max_features=None, min_samples_split=2, splitter=best;, score=0.798 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=2, max_features=None, min_samples_split=2, splitter=best;, score=0.815 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=2, max_features=None, min_samples_split=2, splitter=best;, score=0.837 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=2, max_features=None, min_samples_split=2, splitter=best;, score=0.677 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=2, max_features=None, min_samples_split=2, splitter=best;, score=0.829 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=2, max_features=None, min_samples_split=2, splitter=random;, score=0.805 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=2, max_features=None, min_samples_split=2, splitter=random;, score=0.759 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=2, max_features=None, min_samples_split=2, splitter=random;, score=0.762 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=2, max_features=None, min_samples_split=2, splitter=random;, score=0.557 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=2, max_features=None, min_samples_split=2, splitter=random;, score=0.629 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=2, max_features=sqrt, min_samples_split=2, splitter=best;, score=0.636 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=2, max_features=sqrt, min_samples_split=2, splitter=best;, score=0.607 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=2, max_features=sqrt, min_samples_split=2, splitter=best;, score=0.699 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=2, max_features=sqrt, min_samples_split=2, splitter=best;, score=0.666 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=2, max_features=sqrt, min_samples_split=2, splitter=best;, score=0.655 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=2, max_features=sqrt, min_samples_split=2, splitter=random;, score=0.558 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=2, max_features=sqrt, min_samples_split=2, splitter=random;, score=0.499 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=2, max_features=sqrt, min_samples_split=2, splitter=random;, score=0.536 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=2, max_features=sqrt, min_samples_split=2, splitter=random;, score=0.508 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=2, max_features=sqrt, min_samples_split=2, splitter=random;, score=0.553 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=2, max_features=log2, min_samples_split=2, splitter=best;, score=0.767 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=2, max_features=log2, min_samples_split=2, splitter=best;, score=0.772 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=2, max_features=log2, min_samples_split=2, splitter=best;, score=0.831 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=2, max_features=log2, min_samples_split=2, splitter=best;, score=0.580 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=2, max_features=log2, min_samples_split=2, splitter=best;, score=0.645 total time=   0.0s
# [CV 1/5] END criterion=friedman_mse, max_depth=2, max_features=log2, min_samples_split=2, splitter=random;, score=0.780 total time=   0.0s
# [CV 2/5] END criterion=friedman_mse, max_depth=2, max_features=log2, min_samples_split=2, splitter=random;, score=0.650 total time=   0.0s
# [CV 3/5] END criterion=friedman_mse, max_depth=2, max_features=log2, min_samples_split=2, splitter=random;, score=0.623 total time=   0.0s
# [CV 4/5] END criterion=friedman_mse, max_depth=2, max_features=log2, min_samples_split=2, splitter=random;, score=0.552 total time=   0.0s
# [CV 5/5] END criterion=friedman_mse, max_depth=2, max_features=log2, min_samples_split=2, splitter=random;, score=0.573 total time=   0.0s
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# [CV 1/5] END learning_rate=0.5, max_depth=3, n_estimators=10;, score=0.451 total time=   0.0s
# [CV 2/5] END learning_rate=0.5, max_depth=3, n_estimators=10;, score=0.465 total time=   0.0s
# [CV 3/5] END learning_rate=0.5, max_depth=3, n_estimators=10;, score=0.453 total time=   0.0s
# [CV 4/5] END learning_rate=0.5, max_depth=3, n_estimators=10;, score=0.403 total time=   0.0s
# [CV 5/5] END learning_rate=0.5, max_depth=3, n_estimators=10;, score=0.449 total time=   0.0s
# [CV 1/5] END learning_rate=0.5, max_depth=3, n_estimators=50;, score=0.462 total time=   0.0s
# [CV 2/5] END learning_rate=0.5, max_depth=3, n_estimators=50;, score=0.479 total time=   0.0s
# [CV 3/5] END learning_rate=0.5, max_depth=3, n_estimators=50;, score=0.463 total time=   0.0s
# [CV 4/5] END learning_rate=0.5, max_depth=3, n_estimators=50;, score=0.424 total time=   0.0s
# [CV 5/5] END learning_rate=0.5, max_depth=3, n_estimators=50;, score=0.465 total time=   0.0s
# [CV 1/5] END learning_rate=0.5, max_depth=5, n_estimators=10;, score=0.449 total time=   0.0s
# [CV 2/5] END learning_rate=0.5, max_depth=5, n_estimators=10;, score=0.470 total time=   0.0s
# [CV 3/5] END learning_rate=0.5, max_depth=5, n_estimators=10;, score=0.459 total time=   0.0s
# [CV 4/5] END learning_rate=0.5, max_depth=5, n_estimators=10;, score=0.408 total time=   0.0s
# [CV 5/5] END learning_rate=0.5, max_depth=5, n_estimators=10;, score=0.437 total time=   0.0s
# [CV 1/5] END learning_rate=0.5, max_depth=5, n_estimators=50;, score=0.445 total time=   0.0s
# [CV 2/5] END learning_rate=0.5, max_depth=5, n_estimators=50;, score=0.475 total time=   0.0s
# [CV 3/5] END learning_rate=0.5, max_depth=5, n_estimators=50;, score=0.464 total time=   0.0s
# [CV 4/5] END learning_rate=0.5, max_depth=5, n_estimators=50;, score=0.438 total time=   0.0s
# [CV 5/5] END learning_rate=0.5, max_depth=5, n_estimators=50;, score=0.445 total time=   0.0s
# [CV 1/5] END learning_rate=0.1, max_depth=3, n_estimators=10;, score=0.060 total time=   0.0s
# [CV 2/5] END learning_rate=0.1, max_depth=3, n_estimators=10;, score=-0.005 total time=   0.0s
# [CV 3/5] END learning_rate=0.1, max_depth=3, n_estimators=10;, score=0.088 total time=   0.0s
# [CV 4/5] END learning_rate=0.1, max_depth=3, n_estimators=10;, score=-0.198 total time=   0.0s
# [CV 5/5] END learning_rate=0.1, max_depth=3, n_estimators=10;, score=0.063 total time=   0.0s
# [CV 1/5] END learning_rate=0.1, max_depth=3, n_estimators=50;, score=0.457 total time=   0.0s
# [CV 2/5] END learning_rate=0.1, max_depth=3, n_estimators=50;, score=0.470 total time=   0.0s
# [CV 3/5] END learning_rate=0.1, max_depth=3, n_estimators=50;, score=0.457 total time=   0.0s
# [CV 4/5] END learning_rate=0.1, max_depth=3, n_estimators=50;, score=0.404 total time=   0.0s
# [CV 5/5] END learning_rate=0.1, max_depth=3, n_estimators=50;, score=0.447 total time=   0.0s
# [CV 1/5] END learning_rate=0.1, max_depth=5, n_estimators=10;, score=0.065 total time=   0.0s
# [CV 2/5] END learning_rate=0.1, max_depth=5, n_estimators=10;, score=0.026 total time=   0.0s
# [CV 3/5] END learning_rate=0.1, max_depth=5, n_estimators=10;, score=0.107 total time=   0.0s
# [CV 4/5] END learning_rate=0.1, max_depth=5, n_estimators=10;, score=-0.149 total time=   0.0s
# [CV 5/5] END learning_rate=0.1, max_depth=5, n_estimators=10;, score=0.090 total time=   0.0s
# [CV 1/5] END learning_rate=0.1, max_depth=5, n_estimators=50;, score=0.459 total time=   0.0s
# [CV 2/5] END learning_rate=0.1, max_depth=5, n_estimators=50;, score=0.467 total time=   0.0s
# [CV 3/5] END learning_rate=0.1, max_depth=5, n_estimators=50;, score=0.460 total time=   0.0s
# [CV 4/5] END learning_rate=0.1, max_depth=5, n_estimators=50;, score=0.416 total time=   0.0s
# [CV 5/5] END learning_rate=0.1, max_depth=5, n_estimators=50;, score=0.446 total time=   0.0s
# 0.5 3 50
# {'learning_rate': 0.5, 'max_depth': 3, 'n_estimators': 50}
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# C:\Users\Lakshita\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# C:\Users\Lakshita\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:413: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# Best Parameters: {'max_depth': None, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 50}
# Best Score: 0.9296381222461573

# %%
X_train_scaled
# Out:
# array([[-0.14528152, -0.15389997,  0.80896027, ..., -0.11396304,
#          0.87802257, -0.28571429],
#        [-0.13639968, -0.15389997,  1.        , ...,  0.7761807 ,
#         -0.27082214,  0.57142857],
#        [-0.2480571 , -0.15389997,  0.79966188, ..., -0.21560575,
#          0.78130038,  0.        ],
#        ...,
#        [-0.57668517,  0.16229451,  1.03127642, ...,  0.93839836,
#          0.01289629, -0.28571429],
#        [ 0.0260111 , -0.15389997,  0.        , ...,  0.        ,
#          0.82213864, -0.51020408],
#        [-0.58049167, -0.15389997,  1.41166526, ...,  0.89938398,
#         -0.01826975,  0.        ]])

# %%
X_test_scaled
# Out:
# array([[-0.62870738,  0.49947534,  1.35164835, -0.46863469,  0.32352941,
#          0.40246407, -0.35357335, -0.51020408],
#        [ 0.15416336, -0.15389997,  0.99323753, -0.37638376,  0.30392157,
#          0.56262834, -0.27941967,  0.        ],
#        [-0.52402855, -0.15389997,  1.05832629, -0.67896679,  0.34313725,
#          1.13963039,  0.20849006,  0.57142857],
#        [-0.4961142 , -0.15389997,  0.84953508, -0.54612546,  0.10784314,
#          0.30800821,  1.31434713, -0.28571429],
#        [-0.81141951, -0.15389997,  1.13271344, -0.14760148,  0.45098039,
#          0.11293634,  0.34927458,  0.        ],
#        [-0.79175258, -0.15389997,  1.53930685, -0.13284133,  0.84313725,
#         -1.32546201,  1.1262762 ,  0.        ],
#        [-0.7479778 , -0.15389997,  1.20879121,  0.29520295,  0.25490196,
#          0.8110883 , -0.8866201 ,  0.        ],
#        [-0.12942109, -0.15389997,  0.        ,  0.02583026, -0.62745098,
#          1.47433265,  0.05158517, -0.42857143],
#        [-0.65979381,  0.14130815,  1.05071851, -0.98523985,  0.43137255,
#          1.15811088,  0.1794734 ,  1.46938776],
#        [-0.68453608, -0.15389997,  1.21386306, -0.78228782, -0.62745098,
#          0.38603696,  1.30467491,  0.57142857],
#        [ 0.1592387 , -0.15389997,  0.90448014,  0.03690037, -0.03921569,
#         -0.9137577 ,  0.38151531,  0.        ],
#        [-0.58049167, -0.15389997,  1.41166526, -0.56826568,  0.11764706,
#          0.89938398, -0.01826975,  1.46938776],
#        [-0.66550357,  0.1406086 ,  1.38461538, -2.33210332, -0.06862745,
#          0.9312115 ,  0.00644815,  0.        ],
#        [-0.13639968, -0.15389997,  1.        ,  0.12915129, -0.05882353,
#          0.6201232 , -0.23428264, -0.51020408],
#        [ 0.14655036, -0.15389997,  0.        ,  0.25830258, -0.62745098,
#          1.20123203, -0.1558302 , -0.42857143],
#        [-0.22077716, -0.15389997,  0.79543533,  0.06273063,  0.05882353,
#         -0.18583162,  0.72541644,  0.57142857],
#        [-0.65979381,  0.14130815,  1.05071851, -0.98523985,  0.43137255,
#          1.15811088,  0.1794734 , -0.51020408],
#        [-0.62870738,  0.49947534,  1.35164835, -0.46863469,  0.32352941,
#          0.40246407, -0.35357335,  0.57142857],
#        [-0.87676447, -0.15389997,  1.40067625, -0.17712177,  0.35294118,
#         -0.07186858,  0.27297152,  0.        ],
#        [-0.38255353, -0.15389997,  0.84868977, -0.94464945,  0.39215686,
#          0.36755647,  1.33584095, -0.51020408],
#        [-0.15099128, -0.15389997,  0.83516484, -0.99261993,  0.62745098,
#          0.20328542,  1.17678667,  0.        ],
#        [-0.27216495, -0.15389997,  1.        ,  0.38745387, -0.17647059,
#          0.63039014, -0.22461042, -0.51020408],
#        [ 0.0260111 , -0.15389997,  0.        ,  0.22140221, -0.62745098,
#          0.        ,  0.82213864, -0.28571429],
#        [-0.2480571 , -0.15389997,  0.79966188,  0.47601476, -0.17647059,
#         -0.21560575,  0.78130038,  1.46938776],
#        [ 0.01395718, -0.15389997,  1.02620456, -0.94095941,  0.34313725,
#          0.8788501 , -0.02149382,  0.57142857],
#        [-0.36796193,  0.2224554 ,  1.03043111, -1.08487085,  0.31372549,
#          0.47535934,  0.0118216 , -0.51020408],
#        [-0.57668517,  0.16229451,  1.03127642, -0.54612546,  0.17647059,
#          0.93839836,  0.01289629,  1.46938776],
#        [-0.36796193,  0.2224554 ,  1.03043111, -1.08487085,  0.31372549,
#          0.47535934,  0.0118216 ,  0.57142857],
#        [-0.16558287, -0.15389997,  1.05748098, -1.53874539,  0.54901961,
#          1.21971253,  0.22998388,  0.57142857],
#        [ 0.15416336, -0.15389997,  0.99323753, -0.37638376,  0.30392157,
#          0.56262834, -0.27941967,  0.57142857],
#        [-0.2740682 , -0.15389997,  0.99915469,  0.37638376, -0.02941176,
#          0.61704312, -0.23535733,  0.        ],
#        [-0.38318795, -0.15389997,  0.84868977, -0.94833948,  0.2254902 ,
#          0.40862423,  1.33369156,  0.        ],
#        [-0.13639968, -0.15389997,  1.        ,  0.29151292, -0.05882353,
#          0.7761807 , -0.27082214,  0.        ],
#        [ 0.111023  , -0.15389997,  0.81318681, -0.62361624,  0.29411765,
#         -0.0698152 ,  0.91886083,  1.46938776],
#        [-0.67755749, -0.15389997,  1.38038884, -0.31365314, -0.18627451,
#          0.9301848 ,  0.00644815,  1.46938776],
#        [ 0.111023  , -0.15389997,  0.81318681, -0.62361624,  0.29411765,
#         -0.0698152 ,  0.91886083,  0.57142857],
#        [ 0.23536875, -0.15389997,  0.        ,  0.25830258, -0.62745098,
#          0.45174538,  0.54271897,  0.        ],
#        [-0.67184774,  0.37355719,  1.41166526, -0.77490775,  0.14705882,
#          0.40349076, -0.10102096, -0.51020408],
#        [-0.2480571 , -0.15389997,  0.79966188,  0.47601476, -0.17647059,
#         -0.21560575,  0.78130038, -0.51020408],
#        [-0.68453608, -0.15389997,  1.21386306, -0.78228782, -0.62745098,
#          0.38603696,  1.30467491,  0.        ],
#        [-0.3038858 , -0.15389997,  0.        , -0.14760148, -0.62745098,
#          1.48870637,  0.5749597 ,  0.        ],
#        [-0.80888184, -0.15389997,  1.51225697,  0.61623616,  0.1372549 ,
#         -1.47843943,  0.9586244 ,  0.        ],
#        [ 0.15987312, -0.15389997,  0.90448014,  0.05166052, -0.02941176,
#         -0.9137577 ,  0.3836647 ,  0.        ],
#        [-0.38636003, -0.15389997,  1.05494505, -0.95940959,  0.1372549 ,
#          1.20533881,  0.21493821,  0.        ],
#        [-0.32038065, -0.15389997,  0.81741336,  0.15867159, -0.18627451,
#         -0.00924025,  0.97581945,  0.57142857],
#        [-0.58049167, -0.15389997,  1.41166526, -0.56826568,  0.11764706,
#          0.89938398, -0.01826975, -0.28571429],
#        [-0.63758921, -0.0587618 ,  1.45731192, -1.04059041, -0.2254902 ,
#          0.39322382,  0.8264374 ,  1.46938776],
#        [-0.38636003, -0.15389997,  1.05494505, -0.95940959,  0.1372549 ,
#          1.20533881,  0.21493821,  1.46938776],
#        [-0.37557494,  0.53235397,  0.20710059, -0.12177122,  0.04901961,
#          1.00410678,  0.06340677, -0.28571429],
#        [-0.52402855, -0.15389997,  1.05832629, -0.67896679,  0.34313725,
#          1.13963039,  0.20849006, -0.51020408],
#        [-0.38255353, -0.15389997,  0.84868977, -0.94464945,  0.39215686,
#          0.36755647,  1.33584095,  0.        ],
#        [-0.44980174, -0.07694998,  1.19188504,  0.77490775, -0.46078431,
#         -0.26694045,  0.23105857,  0.        ],
#        [-0.23409992, -0.15389997,  0.        ,  0.33210332, -0.62745098,
#          0.        ,  1.13379903,  1.26530612],
#        [-0.52402855, -0.15389997,  1.05832629, -0.85239852,  0.34313725,
#          1.23305955,  0.24825363,  0.57142857],
#        [-0.2740682 , -0.15389997,  0.99915469,  0.37638376, -0.02941176,
#          0.61704312, -0.23535733, -0.51020408],
#        [-0.4961142 , -0.15389997,  0.84953508, -0.54612546,  0.10784314,
#          0.30800821,  1.31434713, -0.51020408],
#        [ 0.02664552, -0.15389997,  0.82333052, -0.900369  ,  0.52941176,
#          0.06057495,  1.03277808,  1.46938776],
#        [ 0.02727994,  0.53025533,  0.20710059, -0.89667897,  0.47058824,
#          0.96201232,  0.03224073,  0.57142857],
#        [-0.34702617,  0.22805177,  1.04649197, -1.63099631,  0.53921569,
#          1.10574949,  0.14185922, -0.51020408],
#        [-0.11356067, -0.15389997,  0.        ,  0.25830258, -0.62745098,
#         -0.80287474,  1.77861365, -0.51020408],
#        [-0.37684377, -0.15389997,  1.47252747, -1.12177122,  0.51960784,
#          0.86550308, -0.04298764,  0.        ],
#        [-0.65979381,  0.14130815,  1.05071851, -0.98523985,  0.43137255,
#          1.15811088,  0.1794734 ,  0.57142857],
#        [-0.81776368, -0.04896817,  1.64835165, -0.33210332, -0.03921569,
#          0.54414784, -0.75765717,  0.        ],
#        [-0.37557494,  0.53235397,  0.20710059, -0.12177122,  0.04901961,
#          1.00410678,  0.06340677, -0.51020408],
#        [-0.79238699, -0.15389997,  1.53846154, -0.14760148,  0.84313725,
#         -1.32443532,  1.12305212,  0.        ],
#        [ 0.02727994,  0.53025533,  0.20710059, -0.89667897,  0.47058824,
#          0.96201232,  0.03224073,  0.        ],
#        [-0.38318795, -0.15389997,  0.84868977, -0.94833948,  0.2254902 ,
#          0.40862423,  1.33369156,  0.57142857],
#        [-0.38255353, -0.15389997,  0.84868977, -0.94464945,  0.39215686,
#          0.36755647,  1.33584095, -0.28571429],
#        [-0.52149088, -0.15389997,  1.06001691, -0.84501845,  0.1372549 ,
#          1.25256674,  0.2632993 , -0.28571429]])

# %%
model
# Out:
# {2: XGBRegressor(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.5, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=3, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=50, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...),
#  0: XGBRegressor(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.5, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=3, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=50, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...),
#  1: XGBRegressor(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.5, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=3, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=50, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)}

# %%
C
# Out:
#       Cement  Blast Furnace Slag _component_2  Fly Ash _component_3  \
# 0      540.0                              0.0                   0.0
# 1      540.0                              0.0                   0.0
# 2      332.5                            142.5                   0.0
# 3      332.5                            142.5                   0.0
# 4      198.6                            132.4                   0.0
# ...      ...                              ...                   ...
# 1025   276.4                            116.0                  90.3
# 1026   322.2                              0.0                 115.6
# 1027   148.5                            139.4                 108.6
# 1028   159.1                            186.7                   0.0
# 1029   260.9                            100.5                  78.3
#
#       Water_component_4  Superplasticizer_component_5  \
# 0                 162.0                           2.5
# 1                 162.0                           2.5
# 2                 228.0                           0.0
# 3                 228.0                           0.0
# 4                 192.0                           0.0
# ...                 ...                           ...
# 1025              179.6                           8.9
# 1026              196.0                          10.4
# 1027              192.7                           6.1
# 1028              175.6                          11.3
# 1029              200.6                           8.6
#
#       Coarse Aggregate_component_6  Fine Aggregate_component_7  Age_day
# 0                           1040.0                       676.0       28
# 1                           1055.0                       676.0       28
# 2                            932.0                       594.0      270
# 3                            932.0                       594.0      365
# 4                            978.4                       825.5      360
# ...                            ...                         ...      ...
# 1025                         870.1                       768.3       28
# 1026                         817.9                       813.4       28
# 1027                         892.4                       780.0       28
# 1028                         989.6                       788.9       28
# 1029                         864.5                       761.5       28
#
# [1030 rows x 8 columns]

# %%
ds_pred=pd.read_csv("Prediction.csv")

# %%
ds_pred
# Out:
#      Cement  Blast Furnace Slag _component_2  Fly Ash _component_3  \
# 0     540.0                              0.0                   0.0
# 1     540.0                              0.0                   0.0
# 2     531.3                              0.0                   0.0
# 3     531.3                              0.0                   0.0
# 4     531.3                              0.0                   0.0
# ..      ...                              ...                   ...
# 279   139.6                            209.4                   0.0
# 280   139.6                            209.4                   0.0
# 281   139.6                            209.4                   0.0
# 282   139.6                            209.4                   0.0
# 283   139.6                            209.4                   0.0
#
#      Water_component_4  Superplasticizer_component_5  \
# 0                162.0                           2.5
# 1                162.0                           2.5
# 2                141.8                          28.2
# 3                141.8                          28.2
# 4                141.8                          28.2
# ..                 ...                           ...
# 279              192.0                           0.0
# 280              192.0                           0.0
# 281              192.0                           0.0
# 282              192.0                           0.0
# 283              192.0                           0.0
#
#      Coarse Aggregate_component_6  Fine Aggregate_component_7  Age_day
# 0                          1040.0                       676.0       28
# 1                          1055.0                       676.0       28
# 2                           852.1                       893.7        3
# 3                           852.1                       893.7        7
# 4                           852.1                       893.7       28
# ..                            ...                         ...      ...
# 279                        1047.0                       806.9        7
# 280                        1047.0                       806.9       28
# 281                        1047.0                       806.9       90
# 282                        1047.0                       806.9      180
# 283                        1047.0                       806.9      360
#
# [284 rows x 8 columns]

# %%
# for column in ds_pred.columns:
#      ds_pred[column]+=1
#      ds_pred[column] = np.log(ds_pred[column])

# %%
ds_pred=scaler.transform(ds_pred)

# %%
ds2=pd.DataFrame(ds_pred, columns=['Cement','Blast Furnace Slag _component_2','Fly Ash _component_3','Water_component_4','Superplasticizer_component_5','Coarse Aggregate_component_6','Fine Aggregate_component_7','Age_day'])

# %%
y_test_predict= kmeans.predict(ds_pred)
# Out:
# C:\Users\Lakshita\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but KMeans was fitted with feature names
#   warnings.warn(

# %%
type(ds_pred)
ds_pred=pd.DataFrame(ds_pred)

# %%
cluster=y_test_predict
ds_pred["Cluster"]=cluster

# %%
result=[]
sum=0
l=pd.DataFrame()

list_of_clusters=ds_pred["Cluster"].unique()    
for i in list_of_clusters:
    folder_path2=original_path+ '/' + str(i)
    os.chdir(folder_path2)
    cluster_data=ds_pred[ds_pred["Cluster"]==i]
    print(cluster_data)
    #print(cluster_data)
    cluster_data=cluster_data.drop("Cluster",axis=1)
    #print(cluster_data)
    ds_pred_2=scaler.transform(cluster_data)
    #print(ds_pred_2)
    ds_pred_2=pd.DataFrame(ds_pred_2)
    l=pd.concat([l,ds_pred_2],axis=1)
    #print(l)
    with open("model_.pkl", 'rb') as model_file:
        load_model = pickle.load(model_file)
        #print(load_model)

        result_i=load_model.predict(ds_pred_2)
        #l["Compresive Strength"]=result_i[0]
        
      
    result.append(result_i)
# Out:
#             0         1    2         3         4         5         6  \
# 0    1.694528 -0.153900  0.0 -0.848708 -0.382353  0.739220 -1.112305
# 1    1.694528 -0.153900  0.0 -0.848708 -0.382353  0.893224 -1.112305
# 2    1.639334 -0.153900  0.0 -1.594096  2.137255 -1.189938  1.227297
# 3    1.639334 -0.153900  0.0 -1.594096  2.137255 -1.189938  1.227297
# 4    1.639334 -0.153900  0.0 -1.594096  2.137255 -1.189938  1.227297
# ..        ...       ...  ...       ...       ...       ...       ...
# 279 -0.845678  1.310948  0.0  0.258303 -0.627451  0.811088  0.294465
# 280 -0.845678  1.310948  0.0  0.258303 -0.627451  0.811088  0.294465
# 281 -0.845678  1.310948  0.0  0.258303 -0.627451  0.811088  0.294465
# 282 -0.845678  1.310948  0.0  0.258303 -0.627451  0.811088  0.294465
# 283 -0.845678  1.310948  0.0  0.258303 -0.627451  0.811088  0.294465
#
#             7  Cluster
# 0    0.000000        0
# 1    0.000000        0
# 2   -0.510204        0
# 3   -0.428571        0
# 4    0.000000        0
# ..        ...      ...
# 279 -0.428571        0
# 280  0.000000        0
# 281  1.265306        0
# 282  3.102041        0
# 283  6.775510        0
#
# [284 rows x 9 columns]
# C:\Users\Lakshita\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but RobustScaler was fitted with feature names
#   warnings.warn(

# %%
type(ds_pred_2)
# Out:
# pandas.core.frame.DataFrame

# %%
type(l)
# Out:
# pandas.core.frame.DataFrame

# %%
ds_pred_2
# Out:
#             0         1    2         3         4         5         6         7
# 0   -1.720574 -0.154977  0.0 -6.857886 -0.664937 -9.930809 -8.389170 -0.571429
# 1   -1.720574 -0.154977  0.0 -6.857886 -0.664937 -9.929228 -8.389170 -0.571429
# 2   -1.720924 -0.154977  0.0 -6.885391 -0.417916 -9.950615 -8.364027 -0.581841
# 3   -1.720924 -0.154977  0.0 -6.885391 -0.417916 -9.950615 -8.364027 -0.580175
# 4   -1.720924 -0.154977  0.0 -6.885391 -0.417916 -9.950615 -8.364027 -0.571429
# ..        ...       ...  ...       ...       ...       ...       ...       ...
# 279 -1.736689 -0.144729  0.0 -6.817037 -0.688966 -9.930071 -8.374052 -0.580175
# 280 -1.736689 -0.144729  0.0 -6.817037 -0.688966 -9.930071 -8.374052 -0.571429
# 281 -1.736689 -0.144729  0.0 -6.817037 -0.688966 -9.930071 -8.374052 -0.545606
# 282 -1.736689 -0.144729  0.0 -6.817037 -0.688966 -9.930071 -8.374052 -0.508122
# 283 -1.736689 -0.144729  0.0 -6.817037 -0.688966 -9.930071 -8.374052 -0.433153
#
# [284 rows x 8 columns]

# %%
result[0][1][0]
# Out:
# 26.144388

# %%
result1=[]
for i in range(len(result)):
    z=len(result[i])
    for j in range(len(result[i])):
        #result([i][j])
        result1.append(result[i][j][0])

# %%
ds_pred_2=pd.DataFrame(l, columns=['Cement','Blast Furnace Slag _component_2','Fly Ash _component_3','Water_component_4','Superplasticizer_component_5','Coarse Aggregate_component_6','Fine Aggregate_component_7','Age_day'])

# %%
type(l)
# Out:
# pandas.core.frame.DataFrame

# %%
l.columns =['Cement','Blast Furnace Slag _component_2','Fly Ash _component_3','Water_component_4','Superplasticizer_component_5','Coarse Aggregate_component_6','Fine Aggregate_component_7','Age_day']

# %%
l["Concrete_compressive _strength"]=result1

# %%
l
# Out:
#        Cement  Blast Furnace Slag _component_2  Fly Ash _component_3  \
# 0   -1.720574                        -0.154977                   0.0
# 1   -1.720574                        -0.154977                   0.0
# 2   -1.720924                        -0.154977                   0.0
# 3   -1.720924                        -0.154977                   0.0
# 4   -1.720924                        -0.154977                   0.0
# ..        ...                              ...                   ...
# 279 -1.736689                        -0.144729                   0.0
# 280 -1.736689                        -0.144729                   0.0
# 281 -1.736689                        -0.144729                   0.0
# 282 -1.736689                        -0.144729                   0.0
# 283 -1.736689                        -0.144729                   0.0
#
#      Water_component_4  Superplasticizer_component_5  \
# 0            -6.857886                     -0.664937
# 1            -6.857886                     -0.664937
# 2            -6.885391                     -0.417916
# 3            -6.885391                     -0.417916
# 4            -6.885391                     -0.417916
# ..                 ...                           ...
# 279          -6.817037                     -0.688966
# 280          -6.817037                     -0.688966
# 281          -6.817037                     -0.688966
# 282          -6.817037                     -0.688966
# 283          -6.817037                     -0.688966
#
#      Coarse Aggregate_component_6  Fine Aggregate_component_7   Age_day  \
# 0                       -9.930809                   -8.389170 -0.571429
# 1                       -9.929228                   -8.389170 -0.571429
# 2                       -9.950615                   -8.364027 -0.581841
# 3                       -9.950615                   -8.364027 -0.580175
# 4                       -9.950615                   -8.364027 -0.571429
# ..                            ...                         ...       ...
# 279                     -9.930071                   -8.374052 -0.580175
# 280                     -9.930071                   -8.374052 -0.571429
# 281                     -9.930071                   -8.374052 -0.545606
# 282                     -9.930071                   -8.374052 -0.508122
# 283                     -9.930071                   -8.374052 -0.433153
#
#      Concrete_compressive _strength
# 0                         26.144388
# 1                         26.144388
# 2                         26.144388
# 3                         26.144388
# 4                         26.144388
# ..                              ...
# 279                       26.144388
# 280                       26.144388
# 281                       26.144388
# 282                       26.144388
# 283                       42.552338
#
# [284 rows x 9 columns]
